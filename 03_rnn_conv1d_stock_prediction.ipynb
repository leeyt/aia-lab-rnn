# %% [markdown]
# # 使用 CNN 來預測 Tesla 股價
#
# The dataset used in this notebook is Tesla stock history from 2014 to 2017. You can find the .csv file in the project folder.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# ## Step 0. Loading dataset

# %%
tesla_stocks = pd.read_csv('data/tesla_stocks.csv')

# %%
tesla_stocks.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   2-Aug-17  318.94  327.12  311.22  325.89  13091462
# 1   1-Aug-17  323.00  324.45  316.13  319.57   8303102
# 2  31-Jul-17  335.50  341.49  321.04  323.47   8535136
# 3  28-Jul-17  336.89  339.60  332.51  335.07   4880414
# 4  27-Jul-17  346.00  347.50  326.29  334.46   8302405

# %%
data_to_use = tesla_stocks['Close'].values

# %%
print('Total number of days in the dataset: {}'.format(len(data_to_use)))
# Out:
# Total number of days in the dataset: 756

# %% [markdown]
# ## Step 1. Data preprocessing

# %% [markdown]
# ### Step 1.1 Scaling data

# %%
scaler = StandardScaler()

# %%
scaled_dataset = scaler.fit_transform(data_to_use.reshape(-1, 1))

# %%
plt.figure(figsize=(12,7), frameon=False, facecolor='brown', edgecolor='blue')
plt.title('Scaled TESLA stocks from August 2014 to August 2017')
plt.xlabel('Days')
plt.ylabel('Scaled value of stocks')
plt.plot(scaled_dataset, label='Stocks data')
plt.legend()
plt.show()

# %%
def window_data(data, window_size):
    X = []
    y = []
    
    i = 0
    while (i + window_size) <= len(data) - 1:
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
        
        i += 1
        
    assert len(X) ==  len(y)
    return X, y

# %% [markdown]
# ### Step 1.2 Windowing the dataset

# %%
X, y = window_data(scaled_dataset, 7)

# %% [markdown]
# ### Step 1.3 Creating Training and Testing sets

# %%
X_train  = np.array(X[:700])
y_train = np.array(y[:700])

X_test = np.array(X[700:])
y_test = np.array(y[700:])

print("X_train size: {}".format(X_train.shape))
print("y_train size: {}".format(y_train.shape))
print("X_test size: {}".format(X_test.shape))
print("y_test size: {}".format(y_test.shape))
# Out:
# X_train size: (700, 7, 1)
# y_train size: (700, 1)
# X_test size: (49, 7, 1)
# y_test size: (49, 1)

# %% [markdown]
# ## Create the Conv1D CNN

# %%
epochs = 200
batch_size = 7

# %%
def output_layer(conv1d_output, in_size, out_size):
    ## global average pooling 1D
    x = tf.reduce_mean(conv1d_output, axis=[1])
    print(x)
    
    weights = tf.Variable(tf.truncated_normal([in_size, out_size], stddev=0.05), name='output_layer_weights')
    bias = tf.Variable(tf.zeros([out_size]), name='output_layer_bias')
    
    output = tf.matmul(x, weights) + bias
    return output

# %%
def opt_loss(logits, targets, learning_rate, grad_clip_margin):
    losses = []
    for i in range(targets.get_shape()[0]):
        losses.append([(tf.pow(logits[i] - targets[i], 2))])
        
    loss = tf.reduce_sum(losses)/(2*batch_size)
    
    # Cliping the gradient loss
    gradients = tf.gradients(loss, tf.trainable_variables())
    clipper_, _ = tf.clip_by_global_norm(gradients, grad_clip_margin)
    optimizer = tf.train.AdamOptimizer(learning_rate)
    train_optimizer = optimizer.apply_gradients(zip(clipper_, tf.trainable_variables()))
    
    return loss, train_optimizer

# %%
class StockPredictionCNN1D(object):
    def __init__(self, learning_rate=0.001, batch_size=7, filter_size=[32, 64], kernel_size=[3,3], number_of_layers=2, 
                number_of_classes=1, gradient_clip_margin=4, window_size=7):
    
        self.inputs = tf.placeholder(tf.float32, [batch_size, window_size, 1], name='input_data')
        self.targets = tf.placeholder(tf.float32, [batch_size, 1], name='targets')

        x = self.inputs
        for i in range(number_of_layers):
            x = tf.layers.conv1d(x, filter_size[i], kernel_size[i])
            x = tf.nn.relu(x)

        self.logits = output_layer(x, filter_size[i], number_of_classes)

        self.loss, self.opt = opt_loss(self.logits, self.targets, learning_rate, gradient_clip_margin)

# %%
tf.reset_default_graph()
model = StockPredictionCNN1D()
# Out:
# Tensor("Mean:0", shape=(7, 64), dtype=float32)

# %%
tf.global_variables()
# Out:
# [<tf.Variable 'conv1d/kernel:0' shape=(3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv1d/bias:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv1d_1/kernel:0' shape=(3, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'conv1d_1/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'output_layer_weights:0' shape=(64, 1) dtype=float32_ref>,
#  <tf.Variable 'output_layer_bias:0' shape=(1,) dtype=float32_ref>,
#  <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>,
#  <tf.Variable 'conv1d/kernel/Adam:0' shape=(3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv1d/kernel/Adam_1:0' shape=(3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'conv1d/bias/Adam:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv1d/bias/Adam_1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'conv1d_1/kernel/Adam:0' shape=(3, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'conv1d_1/kernel/Adam_1:0' shape=(3, 32, 64) dtype=float32_ref>,
# ...

# %% [markdown]
# ## Train the network

# %%
session =  tf.Session()

# %%
session.run(tf.global_variables_initializer())

# %%
from datetime import datetime

for i in range(epochs):
    trained_scores = []
    
    j = 0
    epoch_loss = []
    while(j + batch_size) <= len(X_train):
        X_batch = X_train[j:j+batch_size]
        y_batch = y_train[j:j+batch_size]
        
        o, c, _ = session.run([model.logits, model.loss, model.opt], feed_dict={
            model.inputs: X_batch, 
            model.targets: y_batch
        })
        
        epoch_loss.append(c)
        trained_scores.append(o)
        j += batch_size
        
    if (i % 30) == 0:
        print(str(datetime.now()),
              'Epoch {}/{}'.format(i, epochs), 
              'Current loss: {}'.format(np.mean(epoch_loss)))
# Out:
# 2018-03-08 18:12:32.723471 Epoch 0/200 Current loss: 0.0098470039665699
# 2018-03-08 18:12:38.261264 Epoch 30/200 Current loss: 0.01072566770017147
# 2018-03-08 18:12:43.578834 Epoch 60/200 Current loss: 0.009686609730124474
# 2018-03-08 18:12:48.821285 Epoch 90/200 Current loss: 0.009068428538739681
# 2018-03-08 18:12:54.180545 Epoch 120/200 Current loss: 0.008400065824389458
# 2018-03-08 18:12:59.424229 Epoch 150/200 Current loss: 0.008132577873766422
# 2018-03-08 18:13:04.750428 Epoch 180/200 Current loss: 0.008133753202855587

# %%
train_results = []
for i in range(len(trained_scores)):
    for j in range(len(trained_scores[i])):
        train_results.append(trained_scores[i][j])

# %%
tests = []
i = 0
while i+batch_size <= len(X_test):
    o = session.run([model.logits], feed_dict={model.inputs:X_test[i:i+batch_size]})
    tests.append(o)
    i += batch_size

# %%
tests_new = []
for i in range(len(tests)):
    for j in range(len(tests[i][0])):
        tests_new.append(tests[i][0][j])

# %%
test_results = []
for i in range(749):
    if i >= 701:
        test_results.append(tests_new[i-701])
    else:
        test_results.append(None)

# %% [markdown]
# ## Plotting predictions from the network

# %%
plt.figure(figsize=(16, 7))
plt.plot(scaled_dataset, label='Original data')
plt.plot(train_results, label='Training data')
plt.plot(test_results, label='Testing data')
plt.legend()
plt.show()

# %%
session.close()
